# %%
import pandas as pd

# %%
df=pd.read_csv('car.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
filter=df.Doors<5
filter
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Doors, dtype: bool

# %%
df[filter]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
km=df['Odometer (KM)']
km
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
df.drop('Odometer (KM)',axis=1,inplace=True)
df
# Out:
#      Make Colour  Doors        Price
# 0  Toyota  White      4   $4,000.00
# 1   Honda    Red      4   $5,000.00
# 2  Toyota   Blue      3   $7,000.00
# 3     BMW  Black      5  $22,000.00
# 4  Nissan  White      4   $3,500.00
# 5  Toyota  Green      4   $4,500.00
# 6   Honda   Blue      4   $7,500.00
# 7   Honda   Blue      4   $7,000.00
# 8  Toyota  White      4   $6,250.00
# 9  Nissan  White      4   $9,700.00

# %%
df['km']=km

# %%
df
# Out:
#      Make Colour  Doors        Price      km
# 0  Toyota  White      4   $4,000.00   150043
# 1   Honda    Red      4   $5,000.00    87899
# 2  Toyota   Blue      3   $7,000.00    32549
# 3     BMW  Black      5  $22,000.00    11179
# 4  Nissan  White      4   $3,500.00   213095
# 5  Toyota  Green      4   $4,500.00    99213
# 6   Honda   Blue      4   $7,500.00    45698
# 7   Honda   Blue      4   $7,000.00    54738
# 8  Toyota  White      4   $6,250.00    60000
# 9  Nissan  White      4   $9,700.00    31600

# %%
df[df.Doors==5]
# Out:
#   Make Colour  Odometer (KM)  Doors        Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
filter1=df.Doors<5
filter1
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Doors, dtype: bool

# %%
filter2=df.km<10000
filter2
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: km, dtype: bool

# %%
df[filter1 & filter2]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Doors, Price, km]
# Index: []

# %%
df.Make.unique()
# Out:
# array(['Toyota', 'Honda', 'BMW', 'Nissan'], dtype=object)

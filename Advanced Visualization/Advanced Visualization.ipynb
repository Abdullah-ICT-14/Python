# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Md.Abdullah\\Python\\Advanced Visualization'

# %%
df=pd.read_csv('P4-Movie-Ratings.csv')
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(df)
# Out:
# 559

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
df.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
df.Film=df.Film.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
df.Genre=df.Genre.astype('category')
df.Year=df.Year.astype('category')

# %%
df.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Joint plot

# %%
j=sns.jointplot(data=df,x='CriticRating',y='AudienceRating')

# %%
j=sns.jointplot(data=df,x='CriticRating',y='AudienceRating',kind='hex')

# %%
j=sns.jointplot(data=df,x='CriticRating',y='BudgetMillions',kind='kde')

# %%
j=sns.jointplot(data=df,x='AudienceRating',y='BudgetMillions',kind='kde')

# %% [markdown]
# ## Histograms

# %%
h=sns.histplot(df.AudienceRating)

# %%
h=sns.distplot(df.AudienceRating,bins=15)

# %%
h=sns.histplot(df.CriticRating)

# %%
h=sns.distplot(df.CriticRating)

# %%
h2=plt.hist(df.AudienceRating,bins=15)

# %%
h2=plt.hist(df.CriticRating,bins=15)

# %% [markdown]
# ## Stacked Histogram

# %%
plt.hist(df.BudgetMillions)
plt.show()

# %%
plt.hist(df[df.Genre=='Drama'].BudgetMillions,bins=15)
plt.hist(df[df.Genre=='Action'].BudgetMillions,color='green',bins=15)
plt.hist(df[df.Genre=='Thriller'].BudgetMillions,color='red',bins=15);

# %%
plt.hist([df[df.Genre=='Drama'].BudgetMillions,df[df.Genre=='Action'].BudgetMillions,df[df.Genre=='Thriller'].BudgetMillions],bins=10)
plt.show()

# %%
plt.hist([df[df.Genre=='Drama'].BudgetMillions,\
          df[df.Genre=='Action'].BudgetMillions,\
          df[df.Genre=='Thriller'].BudgetMillions],bins=10,stacked=True)
plt.show()

# %%
for i in df.Genre.cat.categories:
    print(i)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=list()
mylabel=[]
for i in df.Genre.cat.categories:
    list1.append(df[df.Genre==i].BudgetMillions)
    mylabel.append(i)

# %%
plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabel);
plt.legend()

# %% [markdown]
# ## KDE plots

# %%
vis1=sns.lmplot(data=df,x='CriticRating',y='AudienceRating',fit_reg=False)

# %%
vis1=sns.lmplot(data=df,x='CriticRating',y='AudienceRating',fit_reg=False,hue='Genre')

# %%
k=sns.kdeplot(x=df.CriticRating,y=df.AudienceRating,shade=True,shade_lowest=False,cmap='Reds')

# %%
k=sns.kdeplot(x=df.CriticRating,y=df.AudienceRating,shade=True,cmap='Reds')

# %% [markdown]
# ## Working with subplots

# %%
sns.set_style('dark')
k2=sns.kdeplot(df.BudgetMillions,df.AudienceRating)
k2
# Out:
# <AxesSubplot:xlabel='BudgetMillions', ylabel='AudienceRating'>

# %%
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating)

# %%
f,ax=plt.subplots(1,2)

# %%
f,ax=plt.subplots(4,3)

# %%
f,axes=plt.subplots(1,2,figsize=(16,6))
k2=sns.kdeplot(df.BudgetMillions,df.AudienceRating,ax=axes[0])
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating,ax=axes[1])
plt.show()

# %%
axes
# Out:
# array([<AxesSubplot:xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <AxesSubplot:xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
f,axes=plt.subplots(2,2,figsize=(16,6),sharex=True,sharey=True)
k2=sns.kdeplot(df.BudgetMillions,df.AudienceRating,ax=axes[0,0])
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating,ax=axes[1,1])
k2.set(xlim=[-20,160])
plt.show()

# %% [markdown]
# ## ViolinPlots and BoxPlots

# %%
v1=sns.violinplot(data=df,x='Genre',y='CriticRating')
v1
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='CriticRating'>

# %%
v2=sns.boxplot(data=df,x='Genre',y='CriticRating')
v2
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='CriticRating'>

# %%
v2=sns.boxplot(data=df[df.Genre=='Drama'],x='Year',y='CriticRating')

# %%
v2=sns.violinplot(data=df[df.Genre=='Drama'],x='Year',y='CriticRating')

# %% [markdown]
# ## Creating a Facet grid

# %%
f=sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')
f=f.map(plt.scatter,'CriticRating','AudienceRating')

# %%
# Can populate with any type of plot
f=sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')
f=f.map(plt.hist,'BudgetMillions')

# %%
f=sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
f=f.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %% [markdown]
# ## Coordinates and Diagonal

# %%
## Controlling axes and Adding Diagonals
f=sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
f=f.map(plt.scatter,'CriticRating','AudienceRating',**kws)
f.set(xlim=(0,100),ylim=(0,100))
for ax in f.axes.flat:
    ax.plot((0,100),(0,100),c='gray',ls='--')
f.add_legend()

# %% [markdown]
# ## Building dashboards

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))
k2=sns.kdeplot(df.BudgetMillions,df.AudienceRating,ax=axes[0,0])
k=sns.kdeplot(x=df.CriticRating,y=df.AudienceRating,shade=True,shade_lowest=False,cmap='Reds',ax=axes[0,0])
#k3=sns.kdeplot(df.BudgetMillions,df.CriticRating,ax=axes[0,1])
v2=sns.violinplot(data=df[df.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[0,1])
k=sns.kdeplot(x=df.CriticRating,y=df.AudienceRating,shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,0])
axes[1,1].h2=plt.hist(df.CriticRating,bins=15)
k2.set(xlim=(-20,60))
k3.set(xlim=(-20,60))
plt.show()

# %% [markdown]
# ## Styling dashboards

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('dark',{"axes.facecolor":"black"})
f,axes=plt.subplots(2,2,figsize=(15,10))
# Plot[0,0]
k2=sns.kdeplot(df.BudgetMillions,df.AudienceRating,ax=axes[0,0],shade=True,shade_lowest=True,cmap='inferno')
k2b=sns.kdeplot(df.BudgetMillions,df.AudienceRating,ax=axes[0,0],cmap='cool')

# Plot[0,1]
#k=sns.kdeplot(x=df.CriticRating,y=df.AudienceRating,shade=True,shade_lowest=False,cmap='Reds',ax=axes[0,0])
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating,ax=axes[0,1],shade=True,shade_lowest=True,cmap='inferno')
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating,ax=axes[0,1],cmap='cool')


# Plot[1,0]
k=sns.kdeplot(x=df.CriticRating,y=df.AudienceRating,shade=True,shade_lowest=False,cmap='Blues_r',ax=axes[1,0])

# Plot[1,1]
v2=sns.violinplot(data=df,x='Year',y='BudgetMillions',ax=axes[1,1],palette="YlOrRd")
#axes[1,1].h2=plt.hist(df.CriticRating,bins=15)

k2.set(xlim=(-20,60))
k3.set(xlim=(-20,60))
plt.show()

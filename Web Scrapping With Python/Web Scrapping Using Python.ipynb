# %%
import requests

# %%
result=requests.get("https://www.prothomalo.com/sports/football/%E0%A6%89%E0%A7%9C%E0%A6%A4%E0%A7%87-%E0%A6%A5%E0%A6%BE%E0%A6%95%E0%A6%BE-%E0%A6%AC%E0%A6%BE%E0%A6%B0%E0%A7%8D%E0%A6%B8%E0%A6%BE%E0%A6%B0-%E0%A6%A1%E0%A6%BE%E0%A6%A8%E0%A6%BE-%E0%A6%9B%E0%A7%87%E0%A6%81%E0%A6%9F%E0%A7%87-%E0%A6%A6%E0%A6%BF%E0%A6%B2-%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%A8%E0%A6%BE%E0%A6%A6%E0%A6%BE")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!DOCTYPE html>\n<html lang="bn">\n  <head>\n    <!-- Google Tag Manager -->\n<script>\n  (function(w, d, s, l, i) {\n    w[l] = w[l] || [];\n    w[l].push({ "gtm.start": new Date().getTime(), event: "gtm.js" });\n    var f = d.getElementsByTagName(s)[0],\n      j = d.createElement(s),\n      dl = l != "dataLayer" ? "&l=" + l : "";\n    j.async = true;\n    j.src = "https://www.googletagmanager.com/gtm.js?id=" + i + dl;\n    f.parentNode.insertBefore(j, f);\n  })(window, document, "script", "dataLayer", "GTM-TDCC7GQ");\n</script>\n<!-- End Google Tag Manager -->    <title>উড়তে থাকা বার্সার ডানা ছেঁটে দিল গ্রানাদা | প্রথম আলো</title><meta name="title" content="উড়তে থাকা বার্সার ডানা ছেঁটে দিল গ্রানাদা | প্রথম আলো"/><meta name="description" content="মেসির গোলে বার্সেলোনা এগিয়ে গেলেও তাদের হারিয়ে রিয়াল মাদ্রিদ ও আতলেতিকো মাদ্রিদের সুবিধা করে দিল গ্রানাদা।"/><meta name="keywords" content="লা লিগা,মেসি,বার্সেলোনা"/><meta name="author" content="খেলা ডেস্ক"/><meta name="news_keywords" cont
# ...

# %%
import bs4

# %%
soup=bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="bn">
# <head>
# <!-- Google Tag Manager -->
# <script>
#   (function(w, d, s, l, i) {
#     w[l] = w[l] || [];
#     w[l].push({ "gtm.start": new Date().getTime(), event: "gtm.js" });
#     var f = d.getElementsByTagName(s)[0],
#       j = d.createElement(s),
#       dl = l != "dataLayer" ? "&l=" + l : "";
#     j.async = true;
#     j.src = "https://www.googletagmanager.com/gtm.js?id=" + i + dl;
#     f.parentNode.insertBefore(j, f);
#   })(window, document, "script", "dataLayer", "GTM-TDCC7GQ");
# </script>
# ...

# %%
soup.select("title")
# Out:
# [<title>উড়তে থাকা বার্সার ডানা ছেঁটে দিল গ্রানাদা | প্রথম আলো</title>]

# %%
soup.select("p")
# Out:
# [<p>রিয়াল মাদ্রিদের মাঠে হারটা বাদ দিলে লিগে আগের ২২ ম্যাচে হারেনি বার্সেলোনা। গ্রানাদার বিপক্ষে নিজেদের মাঠে আজ যখন নামছিলেন মেসিরা, সামনে সমীকরণটা ছিল – জিতলেই লিগের শীর্ষে উঠে যাবেন।</p>,
#  <p>কিন্তু এই মৌসুমে শিরোপার লড়াইয়ে একের পর এক টুইস্ট দেখানো লা লিগা সেটি হতে দিল না। পিছিয়ে পড়েও বার্সার মাঠ থেকে ২-১ গোলের জয় নিয়ে গেল গ্রানাদা! ক্যাম্প ন্যু-তে প্রথম এই জয়ে শুধু তো নিজেদের ইতিহাসই গড়েনি, উড়তে থাকা বার্সার ডানাও যেন ছেঁটে দিয়েছে গ্রানাদা!</p>,
#  <p>গ্রানাদা জিতে আগামী মৌসুমের ইউরোপা লিগে খেলার স্বপ্ন তো বাঁচিয়ে রাখলই, পাশাপাশি সবচেয়ে বড় উপকারটা করে দিয়ে গেছে আতলেতিকো মাদ্রিদ ও রিয়াল মাদ্রিদের। কেন? তা বলবে পয়েন্ট তালিকা।</p>,
# ...

# %%
soup.select("img")
# Out:
# [<img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=VTJem1aIF5R1fn" style="display:none" width="1"/>,
#  <img class="contributor-image contributorImage-m__contributor-image__3EVf3" src="https://assets.prothomalo.com/prothomalo/assets/default-author-image-65aeccf65e75d544d490.svg"/>,
#  <img alt="মেসিরা দারুণ সুযোগ হারিয়েছেন।  " class="picture" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
#  <img alt="default-image" class="picture default-image" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
#  <img alt="default-image" class="picture default-image" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
#  <img alt="default-image" class="picture default-image" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
# ...

# %%
soup.select("title")[0]
# Out:
# <title>উড়তে থাকা বার্সার ডানা ছেঁটে দিল গ্রানাদা | প্রথম আলো</title>

# %%
soup.select("title")[0].getText()
# Out:
# 'উড়তে থাকা বার্সার ডানা ছেঁটে দিল গ্রানাদা | প্রথম আলো'

# %%
first_paragrap=soup.select("p")[0]

# %%
first_paragrap
# Out:
# <p>রিয়াল মাদ্রিদের মাঠে হারটা বাদ দিলে লিগে আগের ২২ ম্যাচে হারেনি বার্সেলোনা। গ্রানাদার বিপক্ষে নিজেদের মাঠে আজ যখন নামছিলেন মেসিরা, সামনে সমীকরণটা ছিল – জিতলেই লিগের শীর্ষে উঠে যাবেন।</p>

# %%
first_paragrap=soup.select("p")[0].getText()

# %%
first_paragrap
# Out:
# 'রিয়াল মাদ্রিদের মাঠে হারটা বাদ দিলে লিগে আগের ২২ ম্যাচে হারেনি বার্সেলোনা। গ্রানাদার বিপক্ষে নিজেদের মাঠে আজ যখন নামছিলেন মেসিরা, সামনে সমীকরণটা ছিল – জিতলেই লিগের শীর্ষে উঠে যাবেন।'

# %% [markdown]
# ----

# %%
res= requests.get("https://en.wikipedia.org/wiki/Muhammad")

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Muhammad - Wikipedia</title>
# ...

# %%
soup.select(".toctext")
# Out:
# [<span class="toctext">Quranic names and appellations</span>,
#  <span class="toctext">Sources of biographical information</span>,
#  <span class="toctext">Quran</span>,
#  <span class="toctext">Early biographies</span>,
#  <span class="toctext">Hadith</span>,
#  <span class="toctext">Pre-Islamic Arabia</span>,
#  <span class="toctext">Life</span>,
#  <span class="toctext">Childhood and early life</span>,
#  <span class="toctext">Beginnings of the Quran</span>,
#  <span class="toctext">Opposition</span>,
#  <span class="toctext">Isra and Mi'raj</span>,
#  <span class="toctext">Last years before Hijra</span>,
#  <span class="toctext">Hijra</span>,
#  <span class="toctext">Migration to Medina</span>,
#  <span class="toctext">Establishment of a new polity</span>,
#  <span class="toctext">Beginning of armed conflict</span>,
#  <span class="toctext">Conflict with Mecca</span>,
#  <span class="toctext">Siege of Medina</span>,
#  <span class="toctext">Truce of Hudaybiyyah</span>,
# ...

# %%
type(soup.select(".toctext")[0])
# Out:
# bs4.element.Tag

# %%
soup.select(".toctext")[0].getText()
# Out:
# 'Quranic names and appellations'

# %%
for i in soup.select(".toctext"):
    print(i)
# Out:
# <span class="toctext">Quranic names and appellations</span>
# <span class="toctext">Sources of biographical information</span>
# <span class="toctext">Quran</span>
# <span class="toctext">Early biographies</span>
# <span class="toctext">Hadith</span>
# <span class="toctext">Pre-Islamic Arabia</span>
# <span class="toctext">Life</span>
# <span class="toctext">Childhood and early life</span>
# <span class="toctext">Beginnings of the Quran</span>
# <span class="toctext">Opposition</span>
# <span class="toctext">Isra and Mi'raj</span>
# <span class="toctext">Last years before Hijra</span>
# <span class="toctext">Hijra</span>
# <span class="toctext">Migration to Medina</span>
# <span class="toctext">Establishment of a new polity</span>
# <span class="toctext">Beginning of armed conflict</span>
# <span class="toctext">Conflict with Mecca</span>
# <span class="toctext">Siege of Medina</span>
# <span class="toctext">Truce of Hudaybiyyah</span>
# <span class="toctext">Final years</span>
# ...

# %%
for i in soup.select(".toctext"):
    print(i.text)
# Out:
# Quranic names and appellations
# Sources of biographical information
# Quran
# Early biographies
# Hadith
# Pre-Islamic Arabia
# Life
# Childhood and early life
# Beginnings of the Quran
# Opposition
# Isra and Mi'raj
# Last years before Hijra
# Hijra
# Migration to Medina
# Establishment of a new polity
# Beginning of armed conflict
# Conflict with Mecca
# Siege of Medina
# Truce of Hudaybiyyah
# Final years
# Conquest of Mecca
# Conquest of Arabia
# Farewell pilgrimage
# Death and tomb
# After Muhammad
# Islamic social reforms
# Appearance
# Household
# Legacy
# Islamic tradition
# Sufism
# Depictions
# Medieval Christians
# European appreciation
# Modern historians
# Other religions
# Criticism
# See also
# Notes
# References
# Bibliography
# Encyclopedias
# Further reading
# Books
# Online
# External links

# %%
res=requests.get("https://en.wikipedia.org/wiki/Deep_Blue_(chess_computer)#:~:text=Deep%20Blue%20was%20a%20chess,champion%20under%20regular%20time%20controls.")

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Deep Blue (chess computer) - Wikipedia</title>
# ...

# %%
soup.select("img")
# Out:
# [<img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=VTJem1aIF5R1fn" style="display:none" width="1"/>,
#  <img class="contributor-image contributorImage-m__contributor-image__3EVf3" src="https://assets.prothomalo.com/prothomalo/assets/default-author-image-65aeccf65e75d544d490.svg"/>,
#  <img alt="মেসিরা দারুণ সুযোগ হারিয়েছেন।  " class="picture" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
#  <img alt="default-image" class="picture default-image" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
#  <img alt="default-image" class="picture default-image" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
#  <img alt="default-image" class="picture default-image" src="https://assets.prothomalo.com/prothomalo/assets/default-card-image-31d7699de5f98c1d195b.svg"/>,
# ...

# %%
soup.select("img")
# Out:
# [<img alt="Deep Blue.jpg" data-file-height="601" data-file-width="400" decoding="async" height="331" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/330px-Deep_Blue.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/b/be/Deep_Blue.jpg 2x" width="220"/>,
#  <img alt="Chess Programming.svg" data-file-height="60" data-file-width="60" decoding="async" height="150" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/52/Chess_Programming.svg/150px-Chess_Programming.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/52/Chess_Programming.svg/225px-Chess_Programming.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/52/Chess_Programming.svg/300px-Chess_Programming.svg.png 2x" width="150"/>,
# ...

# %%
soup.select(".thumbimage")
# Out:
# [<img alt="" class="thumbimage" data-file-height="600" data-file-width="800" decoding="async" height="165" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Kasparov_Magath_1985_Hamburg-2.png/220px-Kasparov_Magath_1985_Hamburg-2.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Kasparov_Magath_1985_Hamburg-2.png/330px-Kasparov_Magath_1985_Hamburg-2.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Kasparov_Magath_1985_Hamburg-2.png/440px-Kasparov_Magath_1985_Hamburg-2.png 2x" width="220"/>]

# %%
computer=soup.select(".thumbimage")[0]

# %%
computer['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Kasparov_Magath_1985_Hamburg-2.png/220px-Kasparov_Magath_1985_Hamburg-2.png'

# %% [markdown]
# <img
# src= "//upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Kasparov_Magath_1985_Hamburg-2.png/220px-Kasparov_Magath_1985_Hamburg-2.png">

# %%
import requests
import bs4

# %%
'http://books.toscrape.com/catalogue/page-1.html'
# Out:
# 'http://books.toscrape.com/catalogue/page-1.html'

# %%
'http://books.toscrape.com/catalogue/page-2.html'
# Out:
# 'http://books.toscrape.com/catalogue/page-2.html'

# %%
base_url='http://books.toscrape.com/catalogue/page-{}.html'

# %%
base_url.format("5")
# Out:
# 'http://books.toscrape.com/catalogue/page-5.html'

# %%
base_url='http://books.toscrape.com/catalogue/page-{}.html'

# %%
res=requests.get(base_url.format(1))

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:30" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
example=soup.select(".product_pod")

# %%
example
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
example[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
two_star_titles = []

for n in range(1,51):

    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup = bs4.BeautifulSoup(res.text,"lxml")
    books = soup.select(".product_pod")
    
    for book in books:
        if len(book.select('.star-rating.Two')) != 0:
            two_star_titles.append(book.select('a')[1]['title'])

# %%
two_star_titles
# Out:
# ['Starving Hearts (Triangular Trade Trilogy, #1)',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas",
#  'How Music Works',
#  'Maude (1883-1993):She Grew Up with the country',
#  "You can't bury them all: Poems",
#  'Reasons to Stay Alive',
#  'Without Borders (Wanderlove #1)',
#  'Soul Reader',
#  'Security',
#  'Saga, Volume 5 (Saga (Collected Editions) #5)',
#  'Reskilling America: Learning to Labor in the Twenty-First Century',
#  'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#  'Obsidian (Lux #1)',
#  'My Paris Kitchen: Recipes and Stories',
#  'Masks and Shadows',
#  'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#  'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#  'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
# ...
